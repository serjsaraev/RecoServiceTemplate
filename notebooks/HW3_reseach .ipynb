# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from rectools import Columns
from rectools.dataset import Dataset
from rectools.model_selection import TimeRangeSplitter
from rectools.metrics import Precision, Recall, MAP, MeanInvUserFreq, Serendipity, calc_metrics
from rectools.dataset.interactions import Interactions
from implicit.nearest_neighbours import CosineRecommender, TFIDFRecommender, BM25Recommender
from rectools.models.implicit_knn import ImplicitItemKNNWrapperModel
from tqdm.notebook import tqdm

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 200)

# %% [markdown]
# ## Data

# %%
interactions = pd.read_csv('../data/kion_train/interactions.csv')
users = pd.read_csv('../data/kion_train/users.csv')
items = pd.read_csv('../data/kion_train/items.csv')

# %%
interactions.rename(columns={'last_watch_dt': Columns.Datetime,
                            'total_dur': Columns.Weight},
                    inplace=True)

interactions['datetime'] = pd.to_datetime(interactions['datetime'])

# %% [markdown]
# ## Prepare train

# %%
n_folds=5
unit='W' 
n_units=1

periods = n_folds + 1
freq = f"{n_units}{unit}"

last_date = interactions[Columns.Datetime].max().normalize()
start_date = last_date - pd.Timedelta(n_folds * n_units + n_units, unit=unit)  
date_range = pd.date_range(start=start_date, periods=periods, freq=freq, tz=last_date.tz)
print(f"Start date and last date of the test fold: {start_date, last_date}")
print(f"Test fold borders: {date_range.values.astype('datetime64[D]')}")

cv = TimeRangeSplitter(
    date_range=date_range,
    filter_already_seen=True,
    filter_cold_items=True,
    filter_cold_users=True,
)
print(f"Real number of folds: {cv.get_n_splits(Interactions(interactions))}")
# Out:
# Start date and last date of the test fold: (Timestamp('2021-07-11 00:00:00'), Timestamp('2021-08-22 00:00:00'))
# Test fold borders: ['2021-07-11' '2021-07-18' '2021-07-25' '2021-08-01' '2021-08-08'
#  '2021-08-15']
# Real number of folds: 5

# %%
(train_ids, test_ids, fold_info) = cv.split(Interactions(interactions), collect_fold_stats=True).__next__()
train = interactions.loc[train_ids]
test = interactions.loc[test_ids]

# %%
users_inv_mapping = dict(enumerate(train['user_id'].unique()))
users_mapping = {v: k for k, v in users_inv_mapping.items()}

# %%
items_inv_mapping = dict(enumerate(train['item_id'].unique()))
items_mapping = {v: k for k, v in items_inv_mapping.items()}

# %%
print(f"users_mapping amount: {len(users_mapping)}")
print(f"items_mapping amount: {len(items_mapping)}")
# Out:
# users_mapping amount: 640144
# items_mapping amount: 14711

# %%
dataset = Dataset.construct(
    interactions_df=train,
    user_features_df=None,
    item_features_df=None
)

# %% [markdown]
# ## CosineRecommender, TFIDFRecommender, UserKNN BMP25 with CV

# %%
k = [10, 20, 30, 50, 100]

models = {}

for i in k:
    
    models[f"CosineRecommender_k_{i}"] = ImplicitItemKNNWrapperModel(model=CosineRecommender(K=i))
    models[f"TFIDFRecommender_k_{i}"] = ImplicitItemKNNWrapperModel(model=TFIDFRecommender(K=i))
    models[f"BM25Recommender_k_{i}"] = ImplicitItemKNNWrapperModel(model=BM25Recommender(K=i))

# %%
metrics = {
    "prec@10": Precision(k=10),
    "recall@10": Recall(k=10),
    "novelty": MeanInvUserFreq(k=10),
    "serendipity": Serendipity(k=10),
}

catalog = train['item_id'].unique()

# %%
metrics_result = {}

fold_iter = cv.split(Interactions(interactions), collect_fold_stats=True)
    
for idx_fold, (train_ids, test_ids, fold_info) in tqdm(enumerate(fold_iter)):
    
    idx_fold += 1
    
    train = interactions.loc[train_ids]
    test = interactions.loc[test_ids]
    
    catalog = train['user_id'].unique()

    dataset = Dataset.construct(
        interactions_df=train,
        user_features_df=None,
        item_features_df=None

    )
        
    for model_name in models:
        

        model = models[model_name]
        model.fit(dataset)
        
        recs = model.recommend(
                test['user_id'].unique(), 
                dataset=dataset, 
                k=10, 
                filter_viewed=False
        )

        metric_values_itemknn = calc_metrics(
                metrics,
                reco=recs,
                interactions=test,
                prev_interactions=train,
                catalog=catalog
            )

        metrics_result[f"{model_name}_fold_{idx_fold}"] = metric_values_itemknn
        metric_values_itemknn.update({"fold" : idx_fold})
# Out:
# 0it [00:00, ?it/s]

# %%
df_metrics = pd.DataFrame.from_dict(metrics_result, orient='index')

# %%
df_metrics
# Out:
#                                  prec@10  recall@10   novelty   serendipity  \
# CosineRecommender_k_10_fold_1   0.021501   0.126566  8.041791  1.055256e-06
# TFIDFRecommender_k_10_fold_1    0.027819   0.158146  6.794618  1.672625e-06
# BM25Recommender_k_10_fold_1     0.040183   0.222010  4.043860  5.120128e-07
# CosineRecommender_k_20_fold_1   0.022033   0.129254  7.946546  1.087935e-06
# TFIDFRecommender_k_20_fold_1    0.028068   0.159188  6.724442  1.673228e-06
# BM25Recommender_k_20_fold_1     0.040361   0.222558  4.004138  5.016682e-07
# CosineRecommender_k_30_fold_1   0.022143   0.129775  7.914110  1.095616e-06
# TFIDFRecommender_k_30_fold_1    0.028116   0.159716  6.698602  1.649734e-06
# BM25Recommender_k_30_fold_1     0.040307   0.222317  4.000939  4.712224e-07
# CosineRecommender_k_50_fold_1   0.022225   0.130320  7.879579  1.108550e-06
# TFIDFRecommender_k_50_fold_1    0.028164   0.160007  6.671864  1.669294e-06
# BM25Recommender_k_50_fold_1     0.040259   0.222209  4.002940  4.692306e-07
# CosineRecommender_k_100_fold_1  0.022427   0.131458  7.839136  1.100789e-06
# TFIDFRecommender_k_100_fold_1   0.028174   0.160266  6.644753  1.647248e-06
# BM25Recommender_k_100_fold_1    0.040232   0.222104  4.009171  4.603474e-07
# CosineRecommender_k_10_fold_2   0.020121   0.114347  8.141277  1.165705e-06
# TFIDFRecommender_k_10_fold_2    0.025970   0.142944  6.894295  1.818293e-06
# BM25Recommender_k_10_fold_2     0.038088   0.203975  4.029193  6.016153e-07
# CosineRecommender_k_20_fold_2   0.020615   0.116876  8.052605  1.218227e-06
# TFIDFRecommender_k_20_fold_2    0.026371   0.144989  6.823019  1.820339e-06
# BM25Recommender_k_20_fold_2     0.038164   0.204317  3.988040  5.548125e-07
# CosineRecommender_k_30_fold_2   0.020667   0.117285  8.024957  1.218587e-06
# TFIDFRecommender_k_30_fold_2    0.026438   0.145387  6.796806  1.831332e-06
# BM25Recommender_k_30_fold_2     0.038095   0.204133  3.984835  5.342581e-07
# CosineRecommender_k_50_fold_2   0.020760   0.117621  7.991979  1.216093e-06
# TFIDFRecommender_k_50_fold_2    0.026527   0.146114  6.768310  1.828341e-06
# BM25Recommender_k_50_fold_2     0.038063   0.204050  3.986634  5.363354e-07
# CosineRecommender_k_100_fold_2  0.020946   0.118661  7.949590  1.218682e-06
# TFIDFRecommender_k_100_fold_2   0.026583   0.146141  6.741620  1.822237e-06
# BM25Recommender_k_100_fold_2    0.038024   0.203848  3.993173  5.368867e-07
# CosineRecommender_k_10_fold_3   0.018210   0.102099  8.080247  1.226162e-06
# TFIDFRecommender_k_10_fold_3    0.023871   0.129983  6.882450  1.895185e-06
# CosineRecommender_k_100_fold_5  0.017608   0.096688  7.970815  1.224913e-06
# TFIDFRecommender_k_100_fold_5   0.023963   0.127629  6.638697  1.838240e-06
# BM25Recommender_k_100_fold_5    0.032491   0.168248  3.929317  4.747817e-07
#
#                                 fold
# CosineRecommender_k_10_fold_1      1
# TFIDFRecommender_k_10_fold_1       1
# BM25Recommender_k_10_fold_1        1
# CosineRecommender_k_20_fold_1      1
# TFIDFRecommender_k_20_fold_1       1
# BM25Recommender_k_20_fold_1        1
# CosineRecommender_k_30_fold_1      1
# TFIDFRecommender_k_30_fold_1       1
# BM25Recommender_k_30_fold_1        1
# CosineRecommender_k_50_fold_1      1
# TFIDFRecommender_k_50_fold_1       1
# BM25Recommender_k_50_fold_1        1
# CosineRecommender_k_100_fold_1     1
# TFIDFRecommender_k_100_fold_1      1
# BM25Recommender_k_100_fold_1       1
# CosineRecommender_k_10_fold_2      2
# TFIDFRecommender_k_10_fold_2       2
# BM25Recommender_k_10_fold_2        2
# CosineRecommender_k_20_fold_2      2
# TFIDFRecommender_k_20_fold_2       2
# BM25Recommender_k_20_fold_2        2
# CosineRecommender_k_30_fold_2      2
# TFIDFRecommender_k_30_fold_2       2
# BM25Recommender_k_30_fold_2        2
# CosineRecommender_k_50_fold_2      2
# TFIDFRecommender_k_50_fold_2       2
# BM25Recommender_k_50_fold_2        2
# CosineRecommender_k_100_fold_2     2
# TFIDFRecommender_k_100_fold_2      2
# BM25Recommender_k_100_fold_2       2
# CosineRecommender_k_10_fold_3      3
# TFIDFRecommender_k_10_fold_3       3
# BM25Recommender_k_10_fold_3        3
# CosineRecommender_k_20_fold_3      3
# TFIDFRecommender_k_20_fold_3       3
# BM25Recommender_k_20_fold_3        3
# CosineRecommender_k_30_fold_3      3
# TFIDFRecommender_k_30_fold_3       3
# BM25Recommender_k_30_fold_3        3
# CosineRecommender_k_50_fold_3      3
# TFIDFRecommender_k_50_fold_3       3
# BM25Recommender_k_50_fold_3        3
# CosineRecommender_k_100_fold_3     3
# TFIDFRecommender_k_100_fold_3      3
# BM25Recommender_k_100_fold_3       3
# CosineRecommender_k_10_fold_4      4
# TFIDFRecommender_k_10_fold_4       4
# BM25Recommender_k_10_fold_4        4
# CosineRecommender_k_20_fold_4      4
# TFIDFRecommender_k_20_fold_4       4
# BM25Recommender_k_20_fold_4        4
# CosineRecommender_k_30_fold_4      4
# TFIDFRecommender_k_30_fold_4       4
# BM25Recommender_k_30_fold_4        4
# CosineRecommender_k_50_fold_4      4
# TFIDFRecommender_k_50_fold_4       4
# BM25Recommender_k_50_fold_4        4
# CosineRecommender_k_100_fold_4     4
# TFIDFRecommender_k_100_fold_4      4
# BM25Recommender_k_100_fold_4       4
# CosineRecommender_k_10_fold_5      5
# TFIDFRecommender_k_10_fold_5       5
# BM25Recommender_k_10_fold_5        5
# CosineRecommender_k_20_fold_5      5
# TFIDFRecommender_k_20_fold_5       5
# BM25Recommender_k_20_fold_5        5
# CosineRecommender_k_30_fold_5      5
# TFIDFRecommender_k_30_fold_5       5
# BM25Recommender_k_30_fold_5        5
# CosineRecommender_k_50_fold_5      5
# TFIDFRecommender_k_50_fold_5       5
# BM25Recommender_k_50_fold_5        5
# CosineRecommender_k_100_fold_5     5
# TFIDFRecommender_k_100_fold_5      5
# BM25Recommender_k_100_fold_5       5
